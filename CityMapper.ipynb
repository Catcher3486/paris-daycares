# %%
import geopy

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
from geopy.extra.rate_limiter import RateLimiter

geolocator = Nominatim(user_agent="daycare-geocoder")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

address = "3 Rue des Haudriettes, 75003 Paris, France"

from src.utils.geocode_address import geocode_address
geocode_address(address)
# Out:
# Geocoding error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=3+Rue+des+Haudriettes%2C+75003+Paris%2C+France&format=json&limit=1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)')))
